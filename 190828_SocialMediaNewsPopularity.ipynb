# %% [markdown]
# <a href="https://colab.research.google.com/github/strangelycutlemon/misc_code_challenges/blob/master/190828_SocialMediaNewsPopularity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00432/Data/'

files = ['Facebook_Economy.csv', 'Facebook_Microsoft.csv',
'Facebook_Obama.csv',
'Facebook_Palestine.csv',
'GooglePlus_Economy.csv',
'GooglePlus_Microsoft.csv',
'GooglePlus_Obama.csv',
'GooglePlus_Palestine.csv',
'LinkedIn_Economy.csv',
'LinkedIn_Microsoft.csv',
'LinkedIn_Obama.csv',
'LinkedIn_Palestine.csv',
'News_Final.csv']

# %%
for i in range(0,13):
  path = url + files[i]
  name = (files[i])[:-4]
  exec("%s = pd.read_csv(path, index_col='IDLink')" % name)

# %%
News_Final.head()
# Out:
#                                                      Title  ... LinkedIn
# IDLink                                                      ...
# 99248.0   Obama Lays Wreath at Arlington National Cemetery  ...       -1
# 10423.0        A Look at the Health of the Chinese Economy  ...       -1
# 18828.0   Nouriel Roubini: Global Economy Not Back to 2008  ...       -1
# 27788.0                          Finland GDP Expands In Q4  ...       -1
# 27789.0  Tourism, govt spending buoys Thai economy in J...  ...       -1
#
# [5 rows x 10 columns]

# %%
Facebook_Economy.head()
# Out:
#         TS1  TS2  TS3  TS4  TS5  TS6  ...  TS139  TS140  TS141  TS142  TS143  TS144
# IDLink                                ...
# 1        -1   -1   -1   -1   -1   -1  ...     13     13     13     13     13     13
# 2        -1   -1   -1   -1   -1   -1  ...     42     42     42     42     42     42
# 3        -1   -1   -1   -1   -1   -1  ...     98     98     98     98     98     98
# 4        -1   -1   -1   -1   -1   -1  ...      7      7      7      7      7      7
# 5        -1   -1   -1   -1   -1   -1  ...     34     34     34     34     34     34
#
# [5 rows x 144 columns]

# %%
News_Final.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe491df60b8>,
# ...
#       dtype=object)

# %%
Facebook_Economy.head()
# Out:
#         TS1  TS2  TS3  TS4  TS5  TS6  ...  TS139  TS140  TS141  TS142  TS143  TS144
# IDLink                                ...
# 1        -1   -1   -1   -1   -1   -1  ...     13     13     13     13     13     13
# 2        -1   -1   -1   -1   -1   -1  ...     42     42     42     42     42     42
# 3        -1   -1   -1   -1   -1   -1  ...     98     98     98     98     98     98
# 4        -1   -1   -1   -1   -1   -1  ...      7      7      7      7      7      7
# 5        -1   -1   -1   -1   -1   -1  ...     34     34     34     34     34     34
#
# [5 rows x 144 columns]

# %%
import seaborn as sns

plt.plot(Facebook_Economy);

# %%
time_totals = Facebook_Economy.sum()

# %%
time_totals.plot()

# Plotting the total popularity of all new items across time.

# %%
Facebook_Economy.iloc[0].plot()

# %%
# Next step is to make subplots of the first 9 rows to compare their profiles over time

# %%
# ----- Failed code

# for i in Facebook_Economy.T:
#   exec("Facebook_Economy.T['%s'].plot()" % i)
# Facebook_Economy.T.head()

# time_bins = pd.cut(Facebook_Economy, 20)
# time_bins.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e1fee3700e03> in <module>()
#       1
# ----> 2 time_bins = pd.cut(Facebook_Economy, 20)
#       3 time_bins.plot()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     187
#     188     # for handling the cut for datetime and timedelta objects
# --> 189     x_is_series, series_index, name, x = _preprocess_for_cut(x)
#     190     x, dtype = _coerce_to_type(x)
#     191
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/tile.py in _preprocess_for_cut(x)
#     512         x = np.asarray(x)
#     513     if x.ndim != 1:
# --> 514         raise ValueError("Input array must be 1 dimensional")
#     515
#     516     return x_is_series, series_index, name, x
#
# ...
